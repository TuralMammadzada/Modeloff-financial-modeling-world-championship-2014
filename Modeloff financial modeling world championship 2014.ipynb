# %%
import numpy as np
import pandas as pd
data = pd.read_excel(r'C:\Users\Acer\Downloads\case.xlsx', sheet_name='Usage', header=None)

# %%
data
# Out:
#                                                0
# 0          3 PM  Mon 24th-Mar-2014___0.384 kwh
# 1                 5AM  15-Aug-2014___1.201  kwh
# 2           __8PM Thu 20-Mar-2014____1.523 kwh
# 3                6PM  23rd-Apr-2014___0.424  kwh
# 4      _1AM  Friday 19th-Dec-2014___0.209  kwh
# 5          _5AM  Tue 19th-Aug-2014___1.228  kwh
# 6            12PM  Mon 7th-Jul-2014___1.296 kwh
# 7               7 AM  Tue 25-Nov-2014__0.437 kwh
# 8                  _8AM  14-Aug-2014__0.523 kwh
# 9               __4PM  25th-Jan-2014__2.052kwh
# 10                4PM   11th-Feb-2014_0.509 kwh
# 11      _1 AM   Friday 11-Jul-2014____0.547 kwh
# 12             __12AM   Sun 28-Dec-2014_0.845kwh
# 13           8 PM  Tue 01-Apr-2014____0.557 kwh
# 14        _3AM   Tue 04th-Feb-2014____0.283 kwh
# 15    _11PM  Sunday 11th-May-2014___0.344  kwh
# 16                7 PM  24-Jun-2014__2.948  kwh
# 17             __1 AM   19th-Jun-2014_0.378 kwh
# 18             __8 PM 23rd-Sep-2014_0.963  kwh
# ...

# %%
data[0]=data[0].str.replace('Tuesday','')

# %%
data[0]=data[0].str.replace('Monday','')

# %%
data[0]=data[0].str.replace('Sunday','')

# %%
data[0]=data[0].str.replace('Wednesday','')

# %%
data[0]=data[0].str.replace('Thursday','')

# %%
data[0]=data[0].str.replace('Friday','')

# %%
data[0]=data[0].str.replace('Saturday','')

# %%
data[0]=data[0].str.replace('Tue','')

# %%
data[0]=data[0].str.replace('Thu','')

# %%
data[0]=data[0].str.replace('Mon','')

# %%
data[0]=data[0].str.replace('Fri','')

# %%
data[0]=data[0].str.replace('Sun','')

# %%
data[0]=data[0].str.replace('Sat','')

# %%
data[0]=data[0].str.replace('Wed','')

# %%
data[0]=data[0].str.replace('th','')

# %%
data[0]=data[0].str.replace('rd','')

# %%
data[0]=data[0].str.replace('nd','')

# %%
data[0]=data[0].str.replace('st','')

# %%
data
# Out:
#                                          0
# 0         3 PM   24-Mar-2014___0.384 kwh
# 1           5AM  15-Aug-2014___1.201  kwh
# 2        __8PM  20-Mar-2014____1.523 kwh
# 3            6PM  23-Apr-2014___0.424  kwh
# 4        _1AM   19-Dec-2014___0.209  kwh
# 5         _5AM   19-Aug-2014___1.228  kwh
# 6           12PM   7-Jul-2014___1.296 kwh
# 7            7 AM   25-Nov-2014__0.437 kwh
# 8            _8AM  14-Aug-2014__0.523 kwh
# 9           __4PM  25-Jan-2014__2.052kwh
# 10            4PM   11-Feb-2014_0.509 kwh
# 11      _1 AM    11-Jul-2014____0.547 kwh
# 12          __12AM    28-Dec-2014_0.845kwh
# 13        8 PM   01-Apr-2014____0.557 kwh
# 14       _3AM    04-Feb-2014____0.283 kwh
# 15      _11PM   11-May-2014___0.344  kwh
# 16          7 PM  24-Jun-2014__2.948  kwh
# 17         __1 AM   19-Jun-2014_0.378 kwh
# 18         __8 PM 23-Sep-2014_0.963  kwh
# 19      _12PM  26-Jul-2014____1.469  kwh
# 20          __11AM   23-Jun-2014_1.017 kwh
# ...

# %%
data=data[0].str.split('2014', expand=True)

# %%
data[1].str.strip()
# Out:
# 0         ___0.384 kwh
# 1        ___1.201  kwh
# 2        ____1.523 kwh
# 3        ___0.424  kwh
# 4        ___0.209  kwh
# 5        ___1.228  kwh
# 6         ___1.296 kwh
# 7          __0.437 kwh
# 8          __0.523 kwh
# 9           __2.052kwh
# 10          _0.509 kwh
# 11       ____0.547 kwh
# 12           _0.845kwh
# 13       ____0.557 kwh
# 14       ____0.283 kwh
# 15       ___0.344  kwh
# 16        __2.948  kwh
# 17          _0.378 kwh
# 18         _0.963  kwh
# 19      ____1.469  kwh
# 20          _1.017 kwh
# 21         _0.626  kwh
# 22       ____0.547 kwh
# 23           _0.578kwh
# 24          _0.392 kwh
# 25        ___0.514 kwh
# 26          _0.147 kwh
# 27        ___0.542 kwh
# 28           __0.89kwh
# 29         __0.546 kwh
#              ...
# 8730    ____0.626  kwh
# 8731        __0.749kwh
# 8732      ___2.208 kwh
# 8733       ___1.904kwh
# 8734      ____1.123kwh
# 8735       ___0.363kwh
# 8736     ___1.624  kwh
# 8737     ___0.324  kwh
# 8738        _0.495 kwh
# ...

# %%
data[1]=data[1].str.replace('_','')

# %%
data[1]=data[1].str.replace('__','')

# %%
data[1]=data[1].str.replace('___','')

# %%
data[1]=data[1].str.replace('____','')

# %%
data[1]=data[1].str.replace('_____','')

# %%
data[1]=data[1].str.replace(' ','')

# %%
data[1].str.strip()
# Out:
# 0       0.384kwh
# 1       1.201kwh
# 2       1.523kwh
# 3       0.424kwh
# 4       0.209kwh
# 5       1.228kwh
# 6       1.296kwh
# 7       0.437kwh
# 8       0.523kwh
# 9       2.052kwh
# 10      0.509kwh
# 11      0.547kwh
# 12      0.845kwh
# 13      0.557kwh
# 14      0.283kwh
# 15      0.344kwh
# 16      2.948kwh
# 17      0.378kwh
# 18      0.963kwh
# 19      1.469kwh
# 20      1.017kwh
# 21      0.626kwh
# 22      0.547kwh
# 23      0.578kwh
# 24      0.392kwh
# 25      0.514kwh
# 26      0.147kwh
# 27      0.542kwh
# 28       0.89kwh
# 29      0.546kwh
#           ...
# 8730    0.626kwh
# 8731    0.749kwh
# 8732    2.208kwh
# 8733    1.904kwh
# 8734    1.123kwh
# 8735    0.363kwh
# 8736    1.624kwh
# 8737    0.324kwh
# 8738    0.495kwh
# 8739    2.203kwh
# 8740     1.00kwh
# 8741    1.343kwh
# 8742    0.918kwh
# 8743    0.202kwh
# 8744     1.64kwh
# 8745     3.20kwh
# 8746    1.895kwh
# 8747     1.17kwh
# 8748    0.994kwh
# 8749     1.21kwh
# 8750    0.271kwh
# ...

# %%
data
# Out:
#                        0         1
# 0         3 PM   24-Mar-  0.384kwh
# 1           5AM  15-Aug-  1.201kwh
# 2         __8PM  20-Mar-  1.523kwh
# 3           6PM  23-Apr-  0.424kwh
# 4         _1AM   19-Dec-  0.209kwh
# 5         _5AM   19-Aug-  1.228kwh
# 6          12PM   7-Jul-  1.296kwh
# 7         7 AM   25-Nov-  0.437kwh
# 8          _8AM  14-Aug-  0.523kwh
# 9         __4PM  25-Jan-  2.052kwh
# 10         4PM   11-Feb-  0.509kwh
# 11      _1 AM    11-Jul-  0.547kwh
# 12     __12AM    28-Dec-  0.845kwh
# 13        8 PM   01-Apr-  0.557kwh
# 14       _3AM    04-Feb-  0.283kwh
# 15       _11PM   11-May-  0.344kwh
# 16         7 PM  24-Jun-  2.948kwh
# 17      __1 AM   19-Jun-  0.378kwh
# 18        __8 PM 23-Sep-  0.963kwh
# 19        _12PM  26-Jul-  1.469kwh
# 20      __11AM   23-Jun-  1.017kwh
# 21       __9 AM  01-Jul-  0.626kwh
# 22       _1PM    11-Feb-  0.547kwh
# 23     __11 AM   23-Dec-  0.578kwh
# 24      __10 PM  20-Dec-  0.392kwh
# 25        10AM   17-May-  0.514kwh
# ...

# %%
data[0]=data[0]+'2014'

# %%
data[0]=data[0].str.replace('_','')

# %%
data[0]=data[0].str.replace('__','')

# %%
data[0]=data[0].str.replace('___','')

# %%
data[0]=data[0].str.replace('____','')

# %%
data[0]=data[0].str.replace('_____','')

# %%
data[0]=data[0].str.replace(' ','')

# %%
data[0]=data[0].str.replace('  ','')

# %%
data[0]=data[0].str.replace('   ','')

# %%
data[0]=data[0].str.replace('    ','')

# %%
data[0]=data[0].str.replace('     ','')

# %%
data[0]=data[0].str.replace('      ','')

# %%
data
# Out:
#                     0         1
# 0      3PM24-Mar-2014  0.384kwh
# 1      5AM15-Aug-2014  1.201kwh
# 2      8PM20-Mar-2014  1.523kwh
# 3      6PM23-Apr-2014  0.424kwh
# 4      1AM19-Dec-2014  0.209kwh
# 5      5AM19-Aug-2014  1.228kwh
# 6      12PM7-Jul-2014  1.296kwh
# 7      7AM25-Nov-2014  0.437kwh
# 8      8AM14-Aug-2014  0.523kwh
# 9      4PM25-Jan-2014  2.052kwh
# 10     4PM11-Feb-2014  0.509kwh
# 11     1AM11-Jul-2014  0.547kwh
# 12    12AM28-Dec-2014  0.845kwh
# 13     8PM01-Apr-2014  0.557kwh
# 14     3AM04-Feb-2014  0.283kwh
# 15    11PM11-May-2014  0.344kwh
# 16     7PM24-Jun-2014  2.948kwh
# 17     1AM19-Jun-2014  0.378kwh
# 18     8PM23-Sep-2014  0.963kwh
# 19    12PM26-Jul-2014  1.469kwh
# 20    11AM23-Jun-2014  1.017kwh
# 21     9AM01-Jul-2014  0.626kwh
# 22     1PM11-Feb-2014  0.547kwh
# 23    11AM23-Dec-2014  0.578kwh
# 24    10PM20-Dec-2014  0.392kwh
# 25    10AM17-May-2014  0.514kwh
# 26    12PM28-Apr-2014  0.147kwh
# 27      1PM8-Mar-2014  0.542kwh
# ...

# %%
data[2]=data[0].str[:3]

# %%
data
# Out:
#                     0         1    2
# 0      3PM24-Mar-2014  0.384kwh  3PM
# 1      5AM15-Aug-2014  1.201kwh  5AM
# 2      8PM20-Mar-2014  1.523kwh  8PM
# 3      6PM23-Apr-2014  0.424kwh  6PM
# 4      1AM19-Dec-2014  0.209kwh  1AM
# 5      5AM19-Aug-2014  1.228kwh  5AM
# 6      12PM7-Jul-2014  1.296kwh  12P
# 7      7AM25-Nov-2014  0.437kwh  7AM
# 8      8AM14-Aug-2014  0.523kwh  8AM
# 9      4PM25-Jan-2014  2.052kwh  4PM
# 10     4PM11-Feb-2014  0.509kwh  4PM
# 11     1AM11-Jul-2014  0.547kwh  1AM
# 12    12AM28-Dec-2014  0.845kwh  12A
# 13     8PM01-Apr-2014  0.557kwh  8PM
# 14     3AM04-Feb-2014  0.283kwh  3AM
# 15    11PM11-May-2014  0.344kwh  11P
# 16     7PM24-Jun-2014  2.948kwh  7PM
# 17     1AM19-Jun-2014  0.378kwh  1AM
# 18     8PM23-Sep-2014  0.963kwh  8PM
# 19    12PM26-Jul-2014  1.469kwh  12P
# 20    11AM23-Jun-2014  1.017kwh  11A
# 21     9AM01-Jul-2014  0.626kwh  9AM
# 22     1PM11-Feb-2014  0.547kwh  1PM
# 23    11AM23-Dec-2014  0.578kwh  11A
# ...

# %%
data[2]=data[2].str.replace('M','')

# %%
data[2]=data[2]+'M'

# %%
data
# Out:
#                     0         1     2
# 0      3PM24-Mar-2014  0.384kwh   3PM
# 1      5AM15-Aug-2014  1.201kwh   5AM
# 2      8PM20-Mar-2014  1.523kwh   8PM
# 3      6PM23-Apr-2014  0.424kwh   6PM
# 4      1AM19-Dec-2014  0.209kwh   1AM
# 5      5AM19-Aug-2014  1.228kwh   5AM
# 6      12PM7-Jul-2014  1.296kwh  12PM
# 7      7AM25-Nov-2014  0.437kwh   7AM
# 8      8AM14-Aug-2014  0.523kwh   8AM
# 9      4PM25-Jan-2014  2.052kwh   4PM
# 10     4PM11-Feb-2014  0.509kwh   4PM
# 11     1AM11-Jul-2014  0.547kwh   1AM
# 12    12AM28-Dec-2014  0.845kwh  12AM
# 13     8PM01-Apr-2014  0.557kwh   8PM
# 14     3AM04-Feb-2014  0.283kwh   3AM
# 15    11PM11-May-2014  0.344kwh  11PM
# 16     7PM24-Jun-2014  2.948kwh   7PM
# 17     1AM19-Jun-2014  0.378kwh   1AM
# 18     8PM23-Sep-2014  0.963kwh   8PM
# 19    12PM26-Jul-2014  1.469kwh  12PM
# 20    11AM23-Jun-2014  1.017kwh  11AM
# 21     9AM01-Jul-2014  0.626kwh   9AM
# 22     1PM11-Feb-2014  0.547kwh   1PM
# 23    11AM23-Dec-2014  0.578kwh  11AM
# ...

# %%
data
# Out:
#                     0         1     2
# 0      3PM24-Mar-2014  0.384kwh   3PM
# 1      5AM15-Aug-2014  1.201kwh   5AM
# 2      8PM20-Mar-2014  1.523kwh   8PM
# 3      6PM23-Apr-2014  0.424kwh   6PM
# 4      1AM19-Dec-2014  0.209kwh   1AM
# 5      5AM19-Aug-2014  1.228kwh   5AM
# 6      12PM7-Jul-2014  1.296kwh  12PM
# 7      7AM25-Nov-2014  0.437kwh   7AM
# 8      8AM14-Aug-2014  0.523kwh   8AM
# 9      4PM25-Jan-2014  2.052kwh   4PM
# 10     4PM11-Feb-2014  0.509kwh   4PM
# 11     1AM11-Jul-2014  0.547kwh   1AM
# 12    12AM28-Dec-2014  0.845kwh  12AM
# 13     8PM01-Apr-2014  0.557kwh   8PM
# 14     3AM04-Feb-2014  0.283kwh   3AM
# 15    11PM11-May-2014  0.344kwh  11PM
# 16     7PM24-Jun-2014  2.948kwh   7PM
# 17     1AM19-Jun-2014  0.378kwh   1AM
# 18     8PM23-Sep-2014  0.963kwh   8PM
# 19    12PM26-Jul-2014  1.469kwh  12PM
# 20    11AM23-Jun-2014  1.017kwh  11AM
# 21     9AM01-Jul-2014  0.626kwh   9AM
# 22     1PM11-Feb-2014  0.547kwh   1PM
# 23    11AM23-Dec-2014  0.578kwh  11AM
# ...

# %%
data[3]=data[0].str.split('PM', expand=True)[1]

# %%
data[4] = ''
data[4] =data[0].str.split('AM', expand=True)[1]

# %%
data
# Out:
#                     0         1     2            3            4
# 0      3PM24-Mar-2014  0.384kwh   3PM  24-Mar-2014         None
# 1      5AM15-Aug-2014  1.201kwh   5AM         None  15-Aug-2014
# 2      8PM20-Mar-2014  1.523kwh   8PM  20-Mar-2014         None
# 3      6PM23-Apr-2014  0.424kwh   6PM  23-Apr-2014         None
# 4      1AM19-Dec-2014  0.209kwh   1AM         None  19-Dec-2014
# 5      5AM19-Aug-2014  1.228kwh   5AM         None  19-Aug-2014
# 6      12PM7-Jul-2014  1.296kwh  12PM   7-Jul-2014         None
# 7      7AM25-Nov-2014  0.437kwh   7AM         None  25-Nov-2014
# 8      8AM14-Aug-2014  0.523kwh   8AM         None  14-Aug-2014
# 9      4PM25-Jan-2014  2.052kwh   4PM  25-Jan-2014         None
# 10     4PM11-Feb-2014  0.509kwh   4PM  11-Feb-2014         None
# 11     1AM11-Jul-2014  0.547kwh   1AM         None  11-Jul-2014
# 12    12AM28-Dec-2014  0.845kwh  12AM         None  28-Dec-2014
# 13     8PM01-Apr-2014  0.557kwh   8PM  01-Apr-2014         None
# ...

# %%
data[3] = data[3].fillna('abc')
data[4] = data[4].fillna('abc')

# %%
data[5]=data[3] + '' + data[4]

# %%
data
# Out:
#                     0         1     2            3            4  \
# 0      3PM24-Mar-2014  0.384kwh   3PM  24-Mar-2014          abc
# 1      5AM15-Aug-2014  1.201kwh   5AM          abc  15-Aug-2014
# 2      8PM20-Mar-2014  1.523kwh   8PM  20-Mar-2014          abc
# 3      6PM23-Apr-2014  0.424kwh   6PM  23-Apr-2014          abc
# 4      1AM19-Dec-2014  0.209kwh   1AM          abc  19-Dec-2014
# 5      5AM19-Aug-2014  1.228kwh   5AM          abc  19-Aug-2014
# 6      12PM7-Jul-2014  1.296kwh  12PM   7-Jul-2014          abc
# 7      7AM25-Nov-2014  0.437kwh   7AM          abc  25-Nov-2014
# 8      8AM14-Aug-2014  0.523kwh   8AM          abc  14-Aug-2014
# 9      4PM25-Jan-2014  2.052kwh   4PM  25-Jan-2014          abc
# 10     4PM11-Feb-2014  0.509kwh   4PM  11-Feb-2014          abc
# 11     1AM11-Jul-2014  0.547kwh   1AM          abc  11-Jul-2014
# 12    12AM28-Dec-2014  0.845kwh  12AM          abc  28-Dec-2014
# 13     8PM01-Apr-2014  0.557kwh   8PM  01-Apr-2014          abc
# ...

# %%
data[5]=data[5].str.replace('abc','')

# %%
data.drop(3,axis=1)
# Out:
#                     0         1     2            4            5
# 0      3PM24-Mar-2014  0.384kwh   3PM          abc  24-Mar-2014
# 1      5AM15-Aug-2014  1.201kwh   5AM  15-Aug-2014  15-Aug-2014
# 2      8PM20-Mar-2014  1.523kwh   8PM          abc  20-Mar-2014
# 3      6PM23-Apr-2014  0.424kwh   6PM          abc  23-Apr-2014
# 4      1AM19-Dec-2014  0.209kwh   1AM  19-Dec-2014  19-Dec-2014
# 5      5AM19-Aug-2014  1.228kwh   5AM  19-Aug-2014  19-Aug-2014
# 6      12PM7-Jul-2014  1.296kwh  12PM          abc   7-Jul-2014
# 7      7AM25-Nov-2014  0.437kwh   7AM  25-Nov-2014  25-Nov-2014
# 8      8AM14-Aug-2014  0.523kwh   8AM  14-Aug-2014  14-Aug-2014
# 9      4PM25-Jan-2014  2.052kwh   4PM          abc  25-Jan-2014
# 10     4PM11-Feb-2014  0.509kwh   4PM          abc  11-Feb-2014
# 11     1AM11-Jul-2014  0.547kwh   1AM  11-Jul-2014  11-Jul-2014
# 12    12AM28-Dec-2014  0.845kwh  12AM  28-Dec-2014  28-Dec-2014
# 13     8PM01-Apr-2014  0.557kwh   8PM          abc  01-Apr-2014
# ...

# %%
data=data.drop(3,axis=1)

# %%
data=data.drop(4,axis=1)

# %%
data=data.drop(0,axis=1)

# %%
l1=['Usage','Hour','Date']

# %%
data.columns=l1

# %%
data
# Out:
#          Usage  Hour         Date
# 0     0.384kwh   3PM  24-Mar-2014
# 1     1.201kwh   5AM  15-Aug-2014
# 2     1.523kwh   8PM  20-Mar-2014
# 3     0.424kwh   6PM  23-Apr-2014
# 4     0.209kwh   1AM  19-Dec-2014
# 5     1.228kwh   5AM  19-Aug-2014
# 6     1.296kwh  12PM   7-Jul-2014
# 7     0.437kwh   7AM  25-Nov-2014
# 8     0.523kwh   8AM  14-Aug-2014
# 9     2.052kwh   4PM  25-Jan-2014
# 10    0.509kwh   4PM  11-Feb-2014
# 11    0.547kwh   1AM  11-Jul-2014
# 12    0.845kwh  12AM  28-Dec-2014
# 13    0.557kwh   8PM  01-Apr-2014
# 14    0.283kwh   3AM  04-Feb-2014
# 15    0.344kwh  11PM  11-May-2014
# 16    2.948kwh   7PM  24-Jun-2014
# 17    0.378kwh   1AM  19-Jun-2014
# 18    0.963kwh   8PM  23-Sep-2014
# 19    1.469kwh  12PM  26-Jul-2014
# 20    1.017kwh  11AM  23-Jun-2014
# 21    0.626kwh   9AM  01-Jul-2014
# 22    0.547kwh   1PM  11-Feb-2014
# 23    0.578kwh  11AM  23-Dec-2014
# 24    0.392kwh  10PM  20-Dec-2014
# 25    0.514kwh  10AM  17-May-2014
# ...

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data['Month_name'] = data['Date'].dt.month_name()

# %%
data['Week'] = data['Date'].dt.weekday_name

# %%
data
# Out:
#          Usage  Hour       Date Month_name       Week
# 0     0.384kwh   3PM 2014-03-24      March     Monday
# 1     1.201kwh   5AM 2014-08-15     August     Friday
# 2     1.523kwh   8PM 2014-03-20      March   Thursday
# 3     0.424kwh   6PM 2014-04-23      April  Wednesday
# 4     0.209kwh   1AM 2014-12-19   December     Friday
# 5     1.228kwh   5AM 2014-08-19     August    Tuesday
# 6     1.296kwh  12PM 2014-07-07       July     Monday
# 7     0.437kwh   7AM 2014-11-25   November    Tuesday
# 8     0.523kwh   8AM 2014-08-14     August   Thursday
# 9     2.052kwh   4PM 2014-01-25    January   Saturday
# 10    0.509kwh   4PM 2014-02-11   February    Tuesday
# 11    0.547kwh   1AM 2014-07-11       July     Friday
# 12    0.845kwh  12AM 2014-12-28   December     Sunday
# 13    0.557kwh   8PM 2014-04-01      April    Tuesday
# 14    0.283kwh   3AM 2014-02-04   February    Tuesday
# 15    0.344kwh  11PM 2014-05-11        May     Sunday
# ...

# %%
data['Usage']=data['Usage'].str.replace('kwh','')

# %%
data['Usage']=data['Usage'].astype(float)

# %%
data['Usage'].describe()
# Out:
# count    8760.000000
# mean        0.781878
# std         0.759824
# min         0.048000
# 25%         0.282000
# 50%         0.523000
# 75%         0.994000
# max         5.141000
# Name: Usage, dtype: float64

# %%
data.groupby(['Month_name']).mean()
# Out:
#                Usage
# Month_name
# April       0.210058
# August      0.851331
# December    0.764434
# February    0.832915
# January     1.401425
# July        1.687532
# June        1.255899
# March       0.565522
# May         0.560695
# November    0.322806
# October     0.421665
# September   0.485675

# %%
data.groupby(['Week']).mean()
# Out:
#               Usage
# Week
# Friday     0.753744
# Monday     0.725945
# Saturday   0.890764
# Sunday     0.898157
# Thursday   0.745458
# Tuesday    0.726058
# Wednesday  0.733943

# %%
l1 = ['12AM','1AM','2AM','3AM','10PM','11PM']

# %%
l2=['5AM','9AM','10AM','1PM']

# %%
l3=['8AM','11AM','12PM']

# %%
l4=['6AM','7AM','2PM','6PM','7PM']

# %%
l5=['4AM','4PM']

# %%
data.loc[data['Hour']=='3PM','Hourly Flex'] = .18

# %%
data.loc[data['Hour']=='9PM','Hourly Flex'] = .11

# %%
data.loc[data['Hour']=='8PM','Hourly Flex'] = .12

# %%
data.loc[data['Hour']=='5PM','Hourly Flex'] = .30

# %%
data.loc[data['Hour'].isin(l5),'Hourly Flex'] = .15

# %%
data.loc[data['Hour'].isin(l4),'Hourly Flex'] = .24

# %%
data.loc[data['Hour'].isin(l3),'Hourly Flex'] = .26

# %%
data.loc[data['Hour'].isin(l2),'Hourly Flex'] = .2

# %%
data.loc[data['Hour'].isin(l1),'Hourly Flex'] = .1

# %%
data['No Flex'] = .21

# %%
data['Hourly Flex'].sum()
# Out:
# 1602.3500000000001

# %%
data['Usage'].sum()
# Out:
# 6849.251

# %%
data.loc[data['Month_name']=="January",'Monthly Flex'] = 0.2

# %%
data.loc[data['Month_name']=="February",'Monthly Flex'] = 0.19

# %%
data.loc[data['Month_name']=="March",'Monthly Flex'] = 0.17

# %%
data.loc[data['Month_name']=="April",'Monthly Flex'] = 0.18

# %%
data.loc[data['Month_name']=="May",'Monthly Flex'] = 0.22

# %%
data.loc[data['Month_name']=="June",'Monthly Flex'] = 0.27

# %%
data.loc[data['Month_name']=="July",'Monthly Flex'] = 0.24

# %%
data.loc[data['Month_name']=="August",'Monthly Flex'] = 0.19

# %%
data.loc[data['Month_name']=="September",'Monthly Flex'] = 0.18

# %%
data.loc[data['Month_name']=="October",'Monthly Flex'] = 0.15

# %%
data.loc[data['Month_name']=="November",'Monthly Flex'] = 0.14

# %%
data.loc[data['Month_name']=="December",'Monthly Flex'] = 0.19

# %%
data['Monthly Flex'].sum()
# Out:
# 1693.92

# %%
data['Hourly Flex'].sum()
# Out:
# 1602.3500000000001
